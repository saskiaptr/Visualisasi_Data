# %% [markdown]
# <a href="https://colab.research.google.com/github/saskiaptr/Visualisasi_Data/blob/main/Praktikum3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Praktikum 3 - Matplotlib - Line Chart
#
# Kelompok 28 - Visualisasi Data
#
# 1. Saskia Putri Ananda - 0110222159
# 2. Rahmi Atika - 0110222279
# 3. Noer Muhammad Ayub - 0110222142

# %% [markdown]
# Import Library

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Dataset

# %%
#sampel data
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
product_A_sales = [10, 20, 15, 25, 30, 45, 40, 50, 60, 55, 65, 70]
product_B_sales = [5, 10, 8, 15, 18, 20, 22, 30, 25, 35, 40, 45]

# %% [markdown]
# Line Plot

# %%
plt.plot(months, product_A_sales)
plt.title('Penjualan Produk A Per Bulan')
plt.xlabel('Bulan')
plt.ylabel('Jumlah Penjualan')
plt.show()

# %% [markdown]
# Line Plot dengan Matplotlib

# %%
#line plot
plt.plot(months, product_A_sales, label='Product A')
plt.plot(months, product_B_sales, label='Product B')
plt.title('Penjualan Produk Per Bulan')
plt.xlabel('Bulan')
plt.ylabel('Jumlah Penjualan')
plt.legend()
plt.show()

# %% [markdown]
# Kustomisasi Line Plot

# %%
#line plot
plt.plot(months, product_A_sales, label='Product A', color='blue', linestyle='--', marker='o')
plt.plot(months, product_B_sales, label='Product B', color='red', linestyle='--', marker='x')
plt.title('Penjualan Produk Per Bulan')
plt.xlabel('Bulan')
plt.ylabel('Jumlah Penjualan')
plt.legend()
plt.grid(True)

# %% [markdown]
# Menambahkan Multiple Lines

# %%
#line plot
plt.plot(months, product_A_sales, label='Product A', color='blue', marker='o')
plt.plot(months, product_B_sales, label='Product B', color='red', marker='x')
plt.title('Penjualan Produk Per Bulan')
plt.xlabel('Bulan')
plt.ylabel('Jumlah Penjualan')
plt.legend()
plt.show()

# %% [markdown]
# Garis Berbeda unutk Menunjukkan Tren

# %%
#Line Plot
plt.plot(months, product_A_sales, label='Product A Trend', linestyle='--', color='blue')
plt.plot(months, product_B_sales, label='Product B Trend', linestyle='--', color='red')
plt.title('Trend Penjualan Produk Per Bulan')
plt.xlabel('Bulan')
plt.ylabel('Jumlah Penjualan')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Subplot untuk Menampilkan Beberapa Grafik

# %%
#Line Plot
fig, axs = plt.subplots(2, 1, figsize=(10, 8))

#produk A
axs[0].plot(months, product_A_sales, label='Product A', color='blue', marker='o')
axs[0].set_title('Penjualan Produk A per Bulan')
axs[0].set_xlabel('Bulan')
axs[0].set_ylabel('Jumlah Penjualan')
axs[0].legend()
axs[0].grid(True)

#produk B
axs[1].plot(months, product_B_sales, label='Product B', color='red', marker='x')
axs[1].set_title('Penjualan Produk B per Bulan')
axs[1].set_xlabel('Bulan')
axs[1].set_ylabel('Jumlah Penjualan')
axs[1].legend()
axs[1].grid(True)

plt.tight_layout()
plt.show()
